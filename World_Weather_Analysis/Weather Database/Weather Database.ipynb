# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
city_data = []

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | clinton
# Processing Record 2 of Set 1 | ostrovnoy
# Processing Record 3 of Set 1 | puerto colombia
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | nelson bay
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | ayer itam
# City not found. Skipping...
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | vostok
# Processing Record 10 of Set 1 | hami
# Processing Record 11 of Set 1 | broome
# Processing Record 12 of Set 1 | college
# Processing Record 13 of Set 1 | brae
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | longyearbyen
# Processing Record 16 of Set 1 | luba
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | vila franca do campo
# Processing Record 20 of Set 1 | porosozero
# Processing Record 21 of Set 1 | nanortalik
# Processing Record 22 of Set 1 | paamiut
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | tashtyp
# Processing Record 28 of Set 1 | isangel
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | ahipara
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | samarai
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | plaeng yao
# Processing Record 37 of Set 1 | shimoda
# Processing Record 38 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 1 | ewa beach
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | cabo san lucas
# Processing Record 42 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 1 | hualmay
# Processing Record 44 of Set 1 | nuuk
# Processing Record 45 of Set 1 | port macquarie
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | novo aripuana
# Processing Record 48 of Set 1 | riyadh
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 2 | chokurdakh
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | kawana waters
# City not found. Skipping...
# Processing Record 4 of Set 2 | marzuq
# Processing Record 5 of Set 2 | saint-philippe
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | waipawa
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 2 | kyshtovka
# Processing Record 10 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 2 | pevek
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | fougamou
# Processing Record 17 of Set 2 | touros
# Processing Record 18 of Set 2 | cayenne
# Processing Record 19 of Set 2 | terney
# Processing Record 20 of Set 2 | honiara
# Processing Record 21 of Set 2 | buluang
# Processing Record 22 of Set 2 | port blair
# Processing Record 23 of Set 2 | campbell river
# Processing Record 24 of Set 2 | katsuura
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | fortuna
# Processing Record 27 of Set 2 | namatanai
# Processing Record 28 of Set 2 | pakokku
# Processing Record 29 of Set 2 | magistralnyy
# Processing Record 30 of Set 2 | labuhan
# Processing Record 31 of Set 2 | havre-saint-pierre
# Processing Record 32 of Set 2 | maceio
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | nome
# Processing Record 36 of Set 2 | torbay
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | georgetown
# Processing Record 39 of Set 2 | kodiak
# Processing Record 40 of Set 2 | ustye
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | maldonado
# Processing Record 44 of Set 2 | havre
# Processing Record 45 of Set 2 | peterhead
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | vanavara
# Processing Record 49 of Set 2 | makakilo city
# Processing Record 50 of Set 2 | lompoc
# Processing Record 1 of Set 3 | manuk mangkaw
# Processing Record 2 of Set 3 | bandarbeyla
# Processing Record 3 of Set 3 | sinnamary
# Processing Record 4 of Set 3 | vardo
# Processing Record 5 of Set 3 | russell
# Processing Record 6 of Set 3 | belmonte
# Processing Record 7 of Set 3 | erdenet
# Processing Record 8 of Set 3 | cherskiy
# Processing Record 9 of Set 3 | yellowknife
# Processing Record 10 of Set 3 | luderitz
# Processing Record 11 of Set 3 | jamestown
# Processing Record 12 of Set 3 | chuy
# Processing Record 13 of Set 3 | winsum
# Processing Record 14 of Set 3 | bluff
# Processing Record 15 of Set 3 | mana
# Processing Record 16 of Set 3 | ranavav
# Processing Record 17 of Set 3 | salto del guaira
# Processing Record 18 of Set 3 | anar darreh
# City not found. Skipping...
# Processing Record 19 of Set 3 | adrar
# Processing Record 20 of Set 3 | cidreira
# Processing Record 21 of Set 3 | nanchong
# Processing Record 22 of Set 3 | geraldton
# Processing Record 23 of Set 3 | saskylakh
# Processing Record 24 of Set 3 | puerto ayora
# Processing Record 25 of Set 3 | souillac
# Processing Record 26 of Set 3 | deyang
# Processing Record 27 of Set 3 | port hardy
# Processing Record 28 of Set 3 | beneditinos
# Processing Record 29 of Set 3 | mahebourg
# Processing Record 30 of Set 3 | aklavik
# Processing Record 31 of Set 3 | umm lajj
# Processing Record 32 of Set 3 | scarborough
# Processing Record 33 of Set 3 | ribeira grande
# Processing Record 34 of Set 3 | port lincoln
# Processing Record 35 of Set 3 | san patricio
# Processing Record 36 of Set 3 | hanko
# Processing Record 37 of Set 3 | tura
# Processing Record 38 of Set 3 | norman wells
# Processing Record 39 of Set 3 | albenga
# Processing Record 40 of Set 3 | tual
# Processing Record 41 of Set 3 | evensk
# Processing Record 42 of Set 3 | deer lake
# Processing Record 43 of Set 3 | inhambane
# Processing Record 44 of Set 3 | shingu
# Processing Record 45 of Set 3 | airai
# Processing Record 46 of Set 3 | harnosand
# Processing Record 47 of Set 3 | zlatoustovsk
# City not found. Skipping...
# Processing Record 48 of Set 3 | esperance
# Processing Record 49 of Set 3 | camacha
# Processing Record 50 of Set 3 | toora-khem
# Processing Record 1 of Set 4 | bengkulu
# Processing Record 2 of Set 4 | les cayes
# Processing Record 3 of Set 4 | karratha
# Processing Record 4 of Set 4 | pokhara
# Processing Record 5 of Set 4 | kieta
# Processing Record 6 of Set 4 | saint george
# Processing Record 7 of Set 4 | bayan
# Processing Record 8 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 4 | vitorino freire
# Processing Record 10 of Set 4 | burica
# City not found. Skipping...
# Processing Record 11 of Set 4 | arraial do cabo
# Processing Record 12 of Set 4 | vetluga
# Processing Record 13 of Set 4 | codrington
# Processing Record 14 of Set 4 | xinzhou
# Processing Record 15 of Set 4 | nanma
# Processing Record 16 of Set 4 | shelburne
# Processing Record 17 of Set 4 | bahir dar
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | yining
# Processing Record 20 of Set 4 | alofi
# Processing Record 21 of Set 4 | nouadhibou
# Processing Record 22 of Set 4 | victoria
# Processing Record 23 of Set 4 | kahului
# Processing Record 24 of Set 4 | hurghada
# Processing Record 25 of Set 4 | tongren
# Processing Record 26 of Set 4 | fairlie
# Processing Record 27 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 4 | port alfred
# Processing Record 30 of Set 4 | saurimo
# Processing Record 31 of Set 4 | kodinsk
# Processing Record 32 of Set 4 | santa cruz cabralia
# Processing Record 33 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 34 of Set 4 | iqaluit
# Processing Record 35 of Set 4 | kruisfontein
# Processing Record 36 of Set 4 | vestmannaeyjar
# Processing Record 37 of Set 4 | lorengau
# Processing Record 38 of Set 4 | boyolangu
# Processing Record 39 of Set 4 | askino
# Processing Record 40 of Set 4 | da-an
# City not found. Skipping...
# Processing Record 41 of Set 4 | coquimbo
# Processing Record 42 of Set 4 | dunedin
# Processing Record 43 of Set 4 | hasaki
# Processing Record 44 of Set 4 | zdvinsk
# Processing Record 45 of Set 4 | mundo nuevo
# Processing Record 46 of Set 4 | sept-iles
# Processing Record 47 of Set 4 | puerto madero
# Processing Record 48 of Set 4 | celestun
# Processing Record 49 of Set 4 | yukhnov
# Processing Record 50 of Set 4 | bentiu
# Processing Record 1 of Set 5 | suna
# Processing Record 2 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 3 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 5 | clarksdale
# Processing Record 5 of Set 5 | poli
# Processing Record 6 of Set 5 | kajaani
# Processing Record 7 of Set 5 | pangnirtung
# Processing Record 8 of Set 5 | caravelas
# Processing Record 9 of Set 5 | yulara
# Processing Record 10 of Set 5 | upernavik
# Processing Record 11 of Set 5 | itarema
# Processing Record 12 of Set 5 | sao raimundo nonato
# Processing Record 13 of Set 5 | sangar
# Processing Record 14 of Set 5 | rutana
# Processing Record 15 of Set 5 | butaritari
# Processing Record 16 of Set 5 | fort nelson
# Processing Record 17 of Set 5 | hvammstangi
# City not found. Skipping...
# Processing Record 18 of Set 5 | guerrero negro
# Processing Record 19 of Set 5 | hervey bay
# Processing Record 20 of Set 5 | puerto maldonado
# Processing Record 21 of Set 5 | ormos korthiou
# City not found. Skipping...
# Processing Record 22 of Set 5 | makat
# Processing Record 23 of Set 5 | san vicente
# Processing Record 24 of Set 5 | nampa
# Processing Record 25 of Set 5 | menongue
# Processing Record 26 of Set 5 | cao bang
# Processing Record 27 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 5 | aswan
# Processing Record 29 of Set 5 | bom jesus
# Processing Record 30 of Set 5 | whitehorse
# Processing Record 31 of Set 5 | namibe
# Processing Record 32 of Set 5 | sistranda
# Processing Record 33 of Set 5 | chatrapur
# Processing Record 34 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 35 of Set 5 | saldanha
# Processing Record 36 of Set 5 | waingapu
# Processing Record 37 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 38 of Set 5 | ponta do sol
# Processing Record 39 of Set 5 | bagotville
# Processing Record 40 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 41 of Set 5 | myskhako
# Processing Record 42 of Set 5 | ilulissat
# Processing Record 43 of Set 5 | dudinka
# Processing Record 44 of Set 5 | mahaicony
# City not found. Skipping...
# Processing Record 45 of Set 5 | tambun
# Processing Record 46 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 5 | ahuimanu
# Processing Record 49 of Set 5 | taylorville
# Processing Record 50 of Set 5 | gao
# Processing Record 1 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 6 | rapar
# Processing Record 3 of Set 6 | jinxiang
# Processing Record 4 of Set 6 | linchuan
# City not found. Skipping...
# Processing Record 5 of Set 6 | atambua
# Processing Record 6 of Set 6 | ola
# Processing Record 7 of Set 6 | tasiilaq
# Processing Record 8 of Set 6 | alice springs
# Processing Record 9 of Set 6 | san quintin
# Processing Record 10 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 6 | omboue
# Processing Record 12 of Set 6 | nanakuli
# Processing Record 13 of Set 6 | armizonskoye
# Processing Record 14 of Set 6 | pangkalanbuun
# Processing Record 15 of Set 6 | talnakh
# Processing Record 16 of Set 6 | rincon
# Processing Record 17 of Set 6 | tuatapere
# Processing Record 18 of Set 6 | zacatepec
# Processing Record 19 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 6 | vila velha
# Processing Record 21 of Set 6 | sao filipe
# Processing Record 22 of Set 6 | beringovskiy
# Processing Record 23 of Set 6 | stade
# Processing Record 24 of Set 6 | dhidhdhoo
# Processing Record 25 of Set 6 | cururupu
# Processing Record 26 of Set 6 | nadym
# Processing Record 27 of Set 6 | bafia
# Processing Record 28 of Set 6 | moron
# Processing Record 29 of Set 6 | tommot
# Processing Record 30 of Set 6 | lukovetskiy
# Processing Record 31 of Set 6 | praxedis guerrero
# Processing Record 32 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 6 | boa vista
# Processing Record 34 of Set 6 | la rioja
# Processing Record 35 of Set 6 | turukhansk
# Processing Record 36 of Set 6 | ramsar
# Processing Record 37 of Set 6 | ende
# Processing Record 38 of Set 6 | dekar
# Processing Record 39 of Set 6 | leh
# Processing Record 40 of Set 6 | nikolskoye
# Processing Record 41 of Set 6 | nieuw amsterdam
# Processing Record 42 of Set 6 | la asuncion
# Processing Record 43 of Set 6 | valdivia
# Processing Record 44 of Set 6 | pedernales
# Processing Record 45 of Set 6 | balikpapan
# Processing Record 46 of Set 6 | kavieng
# Processing Record 47 of Set 6 | khandyga
# Processing Record 48 of Set 6 | canterbury
# Processing Record 49 of Set 6 | paita
# Processing Record 50 of Set 6 | saint-augustin
# Processing Record 1 of Set 7 | huarmey
# Processing Record 2 of Set 7 | manutuke
# Processing Record 3 of Set 7 | buin
# Processing Record 4 of Set 7 | dagana
# Processing Record 5 of Set 7 | bethel
# Processing Record 6 of Set 7 | alta floresta
# Processing Record 7 of Set 7 | wattegama
# Processing Record 8 of Set 7 | carroll
# Processing Record 9 of Set 7 | ouadda
# Processing Record 10 of Set 7 | wau
# Processing Record 11 of Set 7 | linhares
# Processing Record 12 of Set 7 | tiarei
# Processing Record 13 of Set 7 | pochutla
# Processing Record 14 of Set 7 | kailua
# Processing Record 15 of Set 7 | vila
# Processing Record 16 of Set 7 | nyurba
# Processing Record 17 of Set 7 | tocopilla
# Processing Record 18 of Set 7 | kaltasy
# Processing Record 19 of Set 7 | kozan
# Processing Record 20 of Set 7 | coihaique
# Processing Record 21 of Set 7 | porto novo
# Processing Record 22 of Set 7 | domoni
# Processing Record 23 of Set 7 | roald
# Processing Record 24 of Set 7 | shama
# Processing Record 25 of Set 7 | araouane
# Processing Record 26 of Set 7 | khatanga
# Processing Record 27 of Set 7 | egvekinot
# Processing Record 28 of Set 7 | yerbogachen
# Processing Record 29 of Set 7 | bilibino
# Processing Record 30 of Set 7 | faanui
# Processing Record 31 of Set 7 | komsomolskiy
# Processing Record 32 of Set 7 | palana
# Processing Record 33 of Set 7 | zhigansk
# Processing Record 34 of Set 7 | pangody
# Processing Record 35 of Set 7 | staryy nadym
# Processing Record 36 of Set 7 | schramberg
# Processing Record 37 of Set 7 | atlantic city
# Processing Record 38 of Set 7 | sabha
# Processing Record 39 of Set 7 | hillsborough
# Processing Record 40 of Set 7 | inongo
# Processing Record 41 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 7 | jalu
# Processing Record 43 of Set 7 | funadhoo
# Processing Record 44 of Set 7 | sola
# Processing Record 45 of Set 7 | adamas
# Processing Record 46 of Set 7 | maisach
# Processing Record 47 of Set 7 | salalah
# Processing Record 48 of Set 7 | suihua
# Processing Record 49 of Set 7 | provideniya
# Processing Record 50 of Set 7 | sibolga
# Processing Record 1 of Set 8 | jumla
# Processing Record 2 of Set 8 | kushima
# Processing Record 3 of Set 8 | concepcion
# Processing Record 4 of Set 8 | ojinaga
# Processing Record 5 of Set 8 | berlevag
# Processing Record 6 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 7 of Set 8 | coahuayana
# Processing Record 8 of Set 8 | clyde river
# Processing Record 9 of Set 8 | mujiayingzi
# Processing Record 10 of Set 8 | northam
# Processing Record 11 of Set 8 | cozumel
# Processing Record 12 of Set 8 | sabang
# Processing Record 13 of Set 8 | gasa
# Processing Record 14 of Set 8 | tarbagatay
# Processing Record 15 of Set 8 | sao felix do xingu
# Processing Record 16 of Set 8 | westport
# Processing Record 17 of Set 8 | epe
# Processing Record 18 of Set 8 | lensk
# Processing Record 19 of Set 8 | cockburn town
# Processing Record 20 of Set 8 | conde
# Processing Record 21 of Set 8 | kitgum
# Processing Record 22 of Set 8 | chernyshevskiy
# Processing Record 23 of Set 8 | bambous virieux
# Processing Record 24 of Set 8 | naze
# Processing Record 25 of Set 8 | atar
# Processing Record 26 of Set 8 | fukue
# Processing Record 27 of Set 8 | vitim
# Processing Record 28 of Set 8 | kharovsk
# Processing Record 29 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 8 | saint anthony
# Processing Record 31 of Set 8 | pasighat
# Processing Record 32 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 8 | copiapo
# Processing Record 34 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 8 | poniatowa
# Processing Record 36 of Set 8 | severo-kurilsk
# Processing Record 37 of Set 8 | williston
# Processing Record 38 of Set 8 | safranbolu
# Processing Record 39 of Set 8 | kalemie
# Processing Record 40 of Set 8 | luganville
# Processing Record 41 of Set 8 | caramay
# Processing Record 42 of Set 8 | batticaloa
# Processing Record 43 of Set 8 | el castillo
# Processing Record 44 of Set 8 | rockhampton
# Processing Record 45 of Set 8 | barra do garcas
# Processing Record 46 of Set 8 | quelimane
# Processing Record 47 of Set 8 | ancud
# Processing Record 48 of Set 8 | verkh-usugli
# Processing Record 49 of Set 8 | san cristobal
# Processing Record 50 of Set 8 | bubaque
# Processing Record 1 of Set 9 | yelizovo
# Processing Record 2 of Set 9 | broken hill
# Processing Record 3 of Set 9 | trincomalee
# Processing Record 4 of Set 9 | lavrentiya
# Processing Record 5 of Set 9 | christchurch
# Processing Record 6 of Set 9 | laguna
# Processing Record 7 of Set 9 | beira
# Processing Record 8 of Set 9 | moyale
# Processing Record 9 of Set 9 | palmer
# Processing Record 10 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 11 of Set 9 | karaton
# Processing Record 12 of Set 9 | creston
# Processing Record 13 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 14 of Set 9 | uvinza
# Processing Record 15 of Set 9 | pacific grove
# Processing Record 16 of Set 9 | ceratu
# Processing Record 17 of Set 9 | flinders
# Processing Record 18 of Set 9 | oranjemund
# Processing Record 19 of Set 9 | khani
# Processing Record 20 of Set 9 | matam
# Processing Record 21 of Set 9 | sumenep
# Processing Record 22 of Set 9 | mareeba
# Processing Record 23 of Set 9 | boone
# Processing Record 24 of Set 9 | ylivieska
# Processing Record 25 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 9 | mao
# Processing Record 27 of Set 9 | jam sahib
# Processing Record 28 of Set 9 | nhulunbuy
# Processing Record 29 of Set 9 | wageningen
# Processing Record 30 of Set 9 | baherden
# Processing Record 31 of Set 9 | raudeberg
# Processing Record 32 of Set 9 | ekibastuz
# Processing Record 33 of Set 9 | panacan
# Processing Record 34 of Set 9 | marsabit
# Processing Record 35 of Set 9 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 36 of Set 9 | el wasta
# City not found. Skipping...
# Processing Record 37 of Set 9 | luocheng
# Processing Record 38 of Set 9 | vyazemskiy
# Processing Record 39 of Set 9 | kaniama
# Processing Record 40 of Set 9 | pemangkat
# Processing Record 41 of Set 9 | banswada
# Processing Record 42 of Set 9 | karwar
# Processing Record 43 of Set 9 | niagara falls
# Processing Record 44 of Set 9 | okato
# Processing Record 45 of Set 9 | paraiso
# Processing Record 46 of Set 9 | prince rupert
# Processing Record 47 of Set 9 | kirakira
# Processing Record 48 of Set 9 | krasnogorsk
# Processing Record 49 of Set 9 | hirara
# Processing Record 50 of Set 9 | meulaboh
# Processing Record 1 of Set 10 | lampang
# Processing Record 2 of Set 10 | yingkou
# Processing Record 3 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 10 | rio gallegos
# Processing Record 5 of Set 10 | fort morgan
# Processing Record 6 of Set 10 | boda
# Processing Record 7 of Set 10 | athabasca
# Processing Record 8 of Set 10 | richards bay
# Processing Record 9 of Set 10 | miranda de ebro
# Processing Record 10 of Set 10 | grindavik
# Processing Record 11 of Set 10 | panalingaan
# Processing Record 12 of Set 10 | hofn
# Processing Record 13 of Set 10 | puerto del rosario
# Processing Record 14 of Set 10 | nkhata bay
# Processing Record 15 of Set 10 | sao joao da barra
# Processing Record 16 of Set 10 | werda
# Processing Record 17 of Set 10 | yar-sale
# Processing Record 18 of Set 10 | skibbereen
# Processing Record 19 of Set 10 | coos bay
# Processing Record 20 of Set 10 | antofagasta
# Processing Record 21 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 10 | berdigestyakh
# Processing Record 23 of Set 10 | mizan teferi
# Processing Record 24 of Set 10 | sibut
# Processing Record 25 of Set 10 | puerto escondido
# Processing Record 26 of Set 10 | ambulu
# Processing Record 27 of Set 10 | abu samrah
# Processing Record 28 of Set 10 | olonets
# Processing Record 29 of Set 10 | nchelenge
# Processing Record 30 of Set 10 | naryan-mar
# Processing Record 31 of Set 10 | banda aceh
# Processing Record 32 of Set 10 | dicabisagan
# Processing Record 33 of Set 10 | pisco
# Processing Record 34 of Set 10 | kpandu
# Processing Record 35 of Set 10 | srednekolymsk
# Processing Record 36 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 10 | capinzal
# Processing Record 38 of Set 10 | auki
# Processing Record 39 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 10 | comodoro rivadavia
# Processing Record 41 of Set 10 | bad wildungen
# Processing Record 42 of Set 10 | tulsipur
# Processing Record 43 of Set 10 | marchena
# Processing Record 44 of Set 10 | prainha
# Processing Record 45 of Set 10 | opatija
# Processing Record 46 of Set 10 | umm kaddadah
# Processing Record 47 of Set 10 | luanda
# Processing Record 48 of Set 10 | tarakan
# Processing Record 49 of Set 10 | korla
# Processing Record 50 of Set 10 | igarka
# Processing Record 1 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 2 of Set 11 | kupang
# Processing Record 3 of Set 11 | tigzirt
# Processing Record 4 of Set 11 | monrovia
# Processing Record 5 of Set 11 | tuchkovo
# Processing Record 6 of Set 11 | pizhma
# Processing Record 7 of Set 11 | westfield
# Processing Record 8 of Set 11 | rivers
# Processing Record 9 of Set 11 | ha
# City not found. Skipping...
# Processing Record 10 of Set 11 | sayat
# Processing Record 11 of Set 11 | mae hong son
# Processing Record 12 of Set 11 | shu
# Processing Record 13 of Set 11 | worcester
# Processing Record 14 of Set 11 | elat
# Processing Record 15 of Set 11 | pozo colorado
# Processing Record 16 of Set 11 | santa maria
# Processing Record 17 of Set 11 | half moon bay
# Processing Record 18 of Set 11 | togur
# Processing Record 19 of Set 11 | roshchino
# Processing Record 20 of Set 11 | castelo do piaui
# Processing Record 21 of Set 11 | altay
# Processing Record 22 of Set 11 | lahaina
# Processing Record 23 of Set 11 | marsa matruh
# Processing Record 24 of Set 11 | aquidauana
# Processing Record 25 of Set 11 | denpasar
# Processing Record 26 of Set 11 | male
# Processing Record 27 of Set 11 | sao paulo de olivenca
# Processing Record 28 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 29 of Set 11 | tazmalt
# Processing Record 30 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 11 | winnemucca
# Processing Record 32 of Set 11 | chicama
# Processing Record 33 of Set 11 | henties bay
# Processing Record 34 of Set 11 | wlodawa
# Processing Record 35 of Set 11 | kavaratti
# Processing Record 36 of Set 11 | mapimi
# Processing Record 37 of Set 11 | channelview
# Processing Record 38 of Set 11 | taoudenni
# Processing Record 39 of Set 11 | asilah
# Processing Record 40 of Set 11 | ihosy
# Processing Record 41 of Set 11 | abu zabad
# Processing Record 42 of Set 11 | qaqortoq
# Processing Record 43 of Set 11 | purificacion
# Processing Record 44 of Set 11 | dessau
# Processing Record 45 of Set 11 | grand baie
# Processing Record 46 of Set 11 | sharkan
# Processing Record 47 of Set 11 | seabra
# Processing Record 48 of Set 11 | palaiokhora
# City not found. Skipping...
# Processing Record 49 of Set 11 | krasnoselkup
# Processing Record 50 of Set 11 | necochea
# Processing Record 1 of Set 12 | saint-louis
# Processing Record 2 of Set 12 | opuwo
# Processing Record 3 of Set 12 | chapais
# Processing Record 4 of Set 12 | maragogi
# Processing Record 5 of Set 12 | berea
# Processing Record 6 of Set 12 | charlestown
# Processing Record 7 of Set 12 | lopatino
# Processing Record 8 of Set 12 | kidal
# Processing Record 9 of Set 12 | khor
# Processing Record 10 of Set 12 | aranzazu
# Processing Record 11 of Set 12 | manaskent
# Processing Record 12 of Set 12 | nemuro
# Processing Record 13 of Set 12 | savannah bight
# Processing Record 14 of Set 12 | lata
# Processing Record 15 of Set 12 | ust-nera
# Processing Record 16 of Set 12 | sokoni
# Processing Record 17 of Set 12 | mezen
# Processing Record 18 of Set 12 | mahibadhoo
# Processing Record 19 of Set 12 | nahrin
# Processing Record 20 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 21 of Set 12 | zhezkazgan
# Processing Record 22 of Set 12 | udaipura
# Processing Record 23 of Set 12 | cap malheureux
# Processing Record 24 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 25 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 12 | salym
# Processing Record 27 of Set 12 | eslov
# Processing Record 28 of Set 12 | glassboro
# Processing Record 29 of Set 12 | banjar
# Processing Record 30 of Set 12 | the valley
# Processing Record 31 of Set 12 | djambala
# Processing Record 32 of Set 12 | viedma
# Processing Record 33 of Set 12 | svetlaya
# Processing Record 34 of Set 12 | talavera de la reina
# Processing Record 35 of Set 12 | blagoyevo
# Processing Record 36 of Set 12 | north bend
# Processing Record 37 of Set 12 | margate
# Processing Record 38 of Set 12 | lagoa
# Processing Record 39 of Set 12 | walvis bay
# Processing Record 40 of Set 12 | jiuquan
# Processing Record 41 of Set 12 | shache
# Processing Record 42 of Set 12 | choya
# Processing Record 43 of Set 12 | hay river
# Processing Record 44 of Set 12 | wijchen
# Processing Record 45 of Set 12 | buraydah
# Processing Record 46 of Set 12 | santa cruz
# Processing Record 47 of Set 12 | awbari
# Processing Record 48 of Set 12 | brusyliv
# Processing Record 49 of Set 12 | general jose eduvigis diaz
# Processing Record 50 of Set 12 | ratekau
# Processing Record 1 of Set 13 | lundazi
# Processing Record 2 of Set 13 | lincoln
# Processing Record 3 of Set 13 | shiyan
# Processing Record 4 of Set 13 | maumere
# Processing Record 5 of Set 13 | san jose
# Processing Record 6 of Set 13 | launceston
# Processing Record 7 of Set 13 | kiunga
# Processing Record 8 of Set 13 | sulecin
# Processing Record 9 of Set 13 | brewster
# Processing Record 10 of Set 13 | makhinjauri
# Processing Record 11 of Set 13 | rafai
# Processing Record 12 of Set 13 | serenje
# Processing Record 13 of Set 13 | okandja
# City not found. Skipping...
# Processing Record 14 of Set 13 | beloha
# Processing Record 15 of Set 13 | sardinia
# Processing Record 16 of Set 13 | moose factory
# Processing Record 17 of Set 13 | tutoia
# Processing Record 18 of Set 13 | sesheke
# Processing Record 19 of Set 13 | pioner
# Processing Record 20 of Set 13 | aste
# Processing Record 21 of Set 13 | loreto
# Processing Record 22 of Set 13 | wick
# Processing Record 23 of Set 13 | havoysund
# Processing Record 24 of Set 13 | atherton
# Processing Record 25 of Set 13 | morant bay
# Processing Record 26 of Set 13 | mecca
# Processing Record 27 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 28 of Set 13 | japura
# Processing Record 29 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 13 | minsk mazowiecki
# Processing Record 31 of Set 13 | veinticinco de mayo
# Processing Record 32 of Set 13 | nea stira
# Processing Record 33 of Set 13 | mount gambier
# Processing Record 34 of Set 13 | ileza
# Processing Record 35 of Set 13 | kumluca
# Processing Record 36 of Set 13 | mathathane
# Processing Record 37 of Set 13 | gimli
# Processing Record 38 of Set 13 | garachine
# Processing Record 39 of Set 13 | praia da vitoria
# Processing Record 40 of Set 13 | suluq
# Processing Record 41 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 13 | myitkyina
# Processing Record 43 of Set 13 | foundiougne
# Processing Record 44 of Set 13 | empalme
# Processing Record 45 of Set 13 | visnes
# Processing Record 46 of Set 13 | mahanoro
# Processing Record 47 of Set 13 | newtownards
# Processing Record 48 of Set 13 | vidim
# Processing Record 49 of Set 13 | hope
# Processing Record 50 of Set 13 | lazaro cardenas
# Processing Record 1 of Set 14 | moa
# Processing Record 2 of Set 14 | calera
# Processing Record 3 of Set 14 | rawson
# Processing Record 4 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 14 | nsanje
# Processing Record 6 of Set 14 | ouro branco
# Processing Record 7 of Set 14 | orapa
# Processing Record 8 of Set 14 | vangaindrano
# Processing Record 9 of Set 14 | bafq
# Processing Record 10 of Set 14 | tumpat
# Processing Record 11 of Set 14 | tokmak
# Processing Record 12 of Set 14 | kologriv
# Processing Record 13 of Set 14 | benghazi
# Processing Record 14 of Set 14 | lyuban
# Processing Record 15 of Set 14 | orlik
# Processing Record 16 of Set 14 | guatire
# Processing Record 17 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 14 | parsabad
# Processing Record 19 of Set 14 | dalton
# Processing Record 20 of Set 14 | binzhou
# Processing Record 21 of Set 14 | fairbanks
# Processing Record 22 of Set 14 | wana
# Processing Record 23 of Set 14 | padang
# Processing Record 24 of Set 14 | poum
# Processing Record 25 of Set 14 | shimanovsk
# Processing Record 26 of Set 14 | olga
# Processing Record 27 of Set 14 | port hedland
# Processing Record 28 of Set 14 | suntar
# Processing Record 29 of Set 14 | asbe teferi
# Processing Record 30 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 14 | doha
# Processing Record 32 of Set 14 | sanjwal
# Processing Record 33 of Set 14 | hovd
# Processing Record 34 of Set 14 | krasnyy chikoy
# Processing Record 35 of Set 14 | thunder bay
# Processing Record 36 of Set 14 | lasa
# Processing Record 37 of Set 14 | methven
# Processing Record 38 of Set 14 | cartagena
# Processing Record 39 of Set 14 | prado
# Processing Record 40 of Set 14 | jaque
# Processing Record 41 of Set 14 | narsaq
# Processing Record 42 of Set 14 | lichuan
# Processing Record 43 of Set 14 | aykhal
# Processing Record 44 of Set 14 | sitka
# Processing Record 45 of Set 14 | barth
# Processing Record 46 of Set 14 | fuzhou
# Processing Record 47 of Set 14 | revelstoke
# Processing Record 48 of Set 14 | gola gokarannath
# Processing Record 49 of Set 14 | chapleau
# Processing Record 50 of Set 14 | le port
# Processing Record 1 of Set 15 | ngawen
# Processing Record 2 of Set 15 | pereyaslovskaya
# Processing Record 3 of Set 15 | haines junction
# Processing Record 4 of Set 15 | kharp
# Processing Record 5 of Set 15 | gamboma
# Processing Record 6 of Set 15 | bani
# Processing Record 7 of Set 15 | mankono
# Processing Record 8 of Set 15 | leningradskiy
# Processing Record 9 of Set 15 | ilo
# Processing Record 10 of Set 15 | rudnya
# Processing Record 11 of Set 15 | corning
# Processing Record 12 of Set 15 | north platte
# Processing Record 13 of Set 15 | mwense
# Processing Record 14 of Set 15 | sao jose da coroa grande
# Processing Record 15 of Set 15 | nuevo imperial
# Processing Record 16 of Set 15 | ghanzi
# Processing Record 17 of Set 15 | fuerte olimpo
# Processing Record 18 of Set 15 | simbahan
# Processing Record 19 of Set 15 | manicore
# Processing Record 20 of Set 15 | selenginsk
# Processing Record 21 of Set 15 | golyshmanovo
# Processing Record 22 of Set 15 | sile
# Processing Record 23 of Set 15 | jesus maria
# Processing Record 24 of Set 15 | genhe
# Processing Record 25 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 26 of Set 15 | nekhayevskiy
# Processing Record 27 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 15 | karlskrona
# Processing Record 29 of Set 15 | careiro da varzea
# Processing Record 30 of Set 15 | zhenlai
# Processing Record 31 of Set 15 | dingle
# Processing Record 32 of Set 15 | te anau
# Processing Record 33 of Set 15 | qandala
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Clinton      US  42.5870  -82.9199     88.95        45
# 1            Ostrovnoy      RU  68.0531   39.5131     42.96        66
# 2      Puerto Colombia      CO  10.9878  -74.9547     87.89        65
# 3         Punta Arenas      CL -53.1500  -70.9167     43.38        71
# 4           Nelson Bay      AU -32.7167  152.1500     53.96        87
# ..                 ...     ...      ...       ...       ...       ...
# 664  Careiro Da Varzea      BR  -3.2003  -59.8119     90.23        52
# 665            Zhenlai      CN  45.8495  123.2973     61.79        52
# 666             Dingle      PH  10.9995  122.6711     77.05        84
# 667            Te Anau      NZ -45.4167  167.7167     36.48        93
# 668            Qandala      SO  11.4720   49.8728     91.29        51
#
#      Cloudiness  Wind Speed Current Description
# 0            20        1.01          few clouds
# 1            26       13.29    scattered clouds
# 2           100        4.61     overcast clouds
# 3           100        9.33     overcast clouds
# 4             1        7.20           clear sky
# ..          ...         ...                 ...
# 664          19        4.29          few clouds
# 665           8        7.02           clear sky
# 666         100        2.57          light rain
# 667          22        1.28          few clouds
# 668          13        2.30          few clouds
#
# [669 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
